# %%
pip install git+https://github.com/ResidentMario/missingno.git
# Out:
# Collecting git+https://github.com/ResidentMario/missingno.git
#   Cloning https://github.com/ResidentMario/missingno.git to /private/var/folders/88/lhd3dzzd50l3lv7f_687j5jc0000gn/T/pip-req-build-hytic5mu
#   Running command git clone --filter=blob:none --quiet https://github.com/ResidentMario/missingno.git /private/var/folders/88/lhd3dzzd50l3lv7f_687j5jc0000gn/T/pip-req-build-hytic5mu
#   Resolved https://github.com/ResidentMario/missingno.git to commit 570fa089ba6338e02342ed990bbc1b0bedc54314
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from missingno==0.5.2) (1.24.4)
# Requirement already satisfied: matplotlib in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from missingno==0.5.2) (3.5.2)
# Requirement already satisfied: scipy in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from missingno==0.5.2) (1.9.1)
# Requirement already satisfied: seaborn in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from missingno==0.5.2) (0.11.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno==0.5.2) (0.11.0)
# Requirement already satisfied: pandas>=0.23 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from seaborn->missingno==0.5.2) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn->missingno==0.5.2) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/christang/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->missingno==0.5.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer 
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy.stats import chi2_contingency
import missingno as msno

# %%
import myutils.preprocessing as pp 
import myutils.visualization as vz
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def read_data(data_dir,fileNames):
    path = os.path.join(data_dir,fileNames)
    df = pd.read_csv(path)
    return df

# %%
data_dir = '../Data'
fName1 = 'train.csv'
fName2 = 'test.csv'
fName3 = 'data_dictionary.csv'

trainData = read_data(data_dir,fName1)
testData = read_data(data_dir,fName2)
dataDict = read_data(data_dir,fName3)

# %% [markdown]
# # Data Understanding and Inspection

# %%
dataDict
# Out:
#                   variable                                        description  \
# 0                dri_score                         Refined disease risk index
# 1            psych_disturb                            Psychiatric disturbance
# 2               cyto_score                                  Cytogenetic score
# 3                 diabetes                                           Diabetes
# 4         hla_match_c_high  Recipient / 1st donor allele level (high resol...
# 5           hla_high_res_8  Recipient / 1st donor allele-level (high resol...
# 6               tbi_status                                                TBI
# 7               arrhythmia                                         Arrhythmia
# 8            hla_low_res_6  Recipient / 1st donor antigen-level (low resol...
# 9               graft_type                                         Graft type
# 10               vent_hist                  History of mechanical ventilation
# 11             renal_issue                           Renal, moderate / severe
# 12             pulm_severe                                  Pulmonary, severe
# 13        prim_disease_hct                            Primary disease for HCT
# 14          hla_high_res_6  Recipient / 1st donor allele-level (high resol...
# 15              cmv_status                     Donor/recipient CMV serostatus
# 16         hla_high_res_10  Recipient / 1st donor allele-level (high resol...
# 17     hla_match_dqb1_high  Recipient / 1st donor allele level (high resol...
# 18           tce_imm_match      T-cell epitope immunogenicity/diversity match
# 19              hla_nmdp_6  Recipient / 1st donor matching at HLA-A(lo),-B...
# 20         hla_match_c_low  Recipient / 1st donor antigen level (low resol...
# 21               rituximab                    Rituximab given in conditioning
# 22      hla_match_drb1_low  Recipient / 1st donor antigen level (low resol...
# 23      hla_match_dqb1_low  Recipient / 1st donor antigen level (low resol...
# 24               prod_type                                       Product type
# 25       cyto_score_detail                     Cytogenetics for DRI (AML/MDS)
# 26  conditioning_intensity            Computed planned conditioning intensity
# 27               ethnicity                                          Ethnicity
# 28                year_hct                                        Year of HCT
# 29                 obesity                                            Obesity
# 30                 mrd_hct                       MRD at time of HCT (AML/ALL)
# 31             in_vivo_tcd         In-vivo T-cell depletion (ATG/alemtuzumab)
# 32               tce_match                            T-cell epitope matching
# 33        hla_match_a_high  Recipient / 1st donor allele level (high resol...
# 34          hepatic_severe                         Hepatic, moderate / severe
# 35               donor_age                                          Donor age
# 36             prior_tumor                                 Solid tumor, prior
# 37         hla_match_b_low  Recipient / 1st donor antigen level (low resol...
# 38            peptic_ulcer                                       Peptic ulcer
# 39              age_at_hct                                         Age at HCT
# 40         hla_match_a_low  Recipient / 1st donor antigen level (low resol...
# 41              gvhd_proph                           Planned GVHD prophylaxis
# 42             rheum_issue                                      Rheumatologic
# 43               sex_match                          Donor/recipient sex match
# 44        hla_match_b_high  Recipient / 1st donor allele level (high resol...
# 45              race_group                                               Race
# 46       comorbidity_score                           Sorror comorbidity score
# 47         karnofsky_score                                         KPS at HCT
# 48            hepatic_mild                                      Hepatic, mild
# 49           tce_div_match                            T-cell epitope matching
# 50           donor_related                        Related vs. unrelated donor
# 51          melphalan_dose                            Melphalan dose (mg/m^2)
# 52           hla_low_res_8  Recipient / 1st donor antigen-level (low resol...
# 53                 cardiac                                            Cardiac
# 54     hla_match_drb1_high  Recipient / 1st donor allele level (high resol...
# 55           pulm_moderate                                Pulmonary, moderate
# 56          hla_low_res_10                                                NaN
# 57                     efs                                Event-free survival
# 58                efs_time                Time to event-free survival, months
#
#            type                                             values
# 0   Categorical  ['Intermediate' 'High' 'N/A - non-malignant in...
# 1   Categorical                        ['Yes' 'No' nan 'Not done']
# 2   Categorical  ['Intermediate' 'Favorable' 'Poor' 'TBD' nan '...
# 3   Categorical                        ['No' 'Yes' nan 'Not done']
# 4     Numerical                                                NaN
# 5     Numerical                                                NaN
# 6   Categorical  ['No TBI' 'TBI + Cy +- Other' 'TBI +- Other, <...
# 7   Categorical                        ['No' nan 'Yes' 'Not done']
# 8     Numerical                                                NaN
# 9   Categorical                 ['Peripheral blood' 'Bone marrow']
# 10  Categorical                                   ['No' 'Yes' nan]
# 11  Categorical                        ['No' nan 'Yes' 'Not done']
# 12  Categorical                        ['No' 'Yes' nan 'Not done']
# 13  Categorical  ['ALL' 'MPN' 'IPA' 'AML' 'MDS' 'Other acute le...
# 14    Numerical                                                NaN
# 15  Categorical                      ['+/-' '+/+' '-/-' '-/+' nan]
# 16    Numerical                                                NaN
# 17    Numerical                                                NaN
# 18  Categorical  ['P/P' nan 'G/G' 'H/H' 'G/B' 'H/B' 'P/H' 'P/G'...
# 19    Numerical                                                NaN
# 20    Numerical                                                NaN
# 21  Categorical                                   ['No' 'Yes' nan]
# 22    Numerical                                                NaN
# 23    Numerical                                                NaN
# 24  Categorical                                        ['PB' 'BM']
# 25  Categorical  ['Intermediate' nan 'TBD' 'Favorable' 'Poor' '...
# 26  Categorical  ['RIC' nan 'NMA' 'MAC' 'TBD' 'No drugs reporte...
# 27  Categorical  ['Not Hispanic or Latino' 'Hispanic or Latino'...
# 28    Numerical                                                NaN
# 29  Categorical                        ['No' 'Yes' nan 'Not done']
# 30  Categorical                        [nan 'Negative' 'Positive']
# 31  Categorical                                   ['Yes' 'No' nan]
# 32  Categorical  ['Permissive' 'Fully matched' nan 'GvH non-per...
# 33    Numerical                                                NaN
# 34  Categorical                        ['No' nan 'Yes' 'Not done']
# 35    Numerical                                                NaN
# 36  Categorical                        ['Yes' 'No' nan 'Not done']
# 37    Numerical                                                NaN
# 38  Categorical                        ['No' nan 'Yes' 'Not done']
# 39    Numerical                                                NaN
# 40    Numerical                                                NaN
# 41  Categorical  ['FK+ MMF +- others' 'Parent Q = yes, but no a...
# 42  Categorical                        ['No' nan 'Yes' 'Not done']
# 43  Categorical                      ['M-M' 'F-F' 'F-M' 'M-F' nan]
# 44    Numerical                                                NaN
# 45  Categorical  ['White' 'Black or African-American'\n 'Native...
# 46    Numerical                                                NaN
# 47    Numerical                                                NaN
# 48  Categorical                        ['No' 'Yes' nan 'Not done']
# 49  Categorical  ['Permissive mismatched' 'Bi-directional non-p...
# 50  Categorical  ['Unrelated' 'Related' 'Multiple donor (non-UC...
# 51  Categorical                   ['N/A, Mel not given' 'MEL' nan]
# 52    Numerical                                                NaN
# 53  Categorical                        ['No' 'Yes' nan 'Not done']
# 54    Numerical                                                NaN
# 55  Categorical                        ['Yes' 'Not done' 'No' nan]
# 56    Numerical                                                NaN
# 57  Categorical                              ['Event' 'Censoring']
# 58    Numerical                                                NaN

# %%
print(trainData.head(5))
# Out:
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6  ...          tce_div_match donor_related  \
# 0            6.0  ...                    NaN     Unrelated
# 1            6.0  ...  Permissive mismatched       Related
# 2            6.0  ...  Permissive mismatched       Related
# 3            6.0  ...  Permissive mismatched     Unrelated
# 4            6.0  ...  Permissive mismatched       Related
#
#        melphalan_dose hla_low_res_8 cardiac  hla_match_drb1_high  \
# 0  N/A, Mel not given           8.0      No                  2.0
# 1  N/A, Mel not given           8.0      No                  2.0
# 2  N/A, Mel not given           8.0      No                  2.0
# 3  N/A, Mel not given           8.0      No                  2.0
# 4                 MEL           8.0      No                  2.0
#
#   pulm_moderate  hla_low_res_10  efs efs_time
# 0            No            10.0  0.0   42.356
# 1           Yes            10.0  1.0    4.672
# 2            No            10.0  0.0   19.793
# 3            No            10.0  0.0  102.349
# 4            No            10.0  0.0   16.223
#
# [5 rows x 60 columns]

# %%
print(trainData.shape)
# Out:
# (28800, 60)

# %%
print(trainData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28800 entries, 0 to 28799
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      28800 non-null  int64
#  1   dri_score               28646 non-null  object
#  2   psych_disturb           26738 non-null  object
#  3   cyto_score              20732 non-null  object
#  4   diabetes                26681 non-null  object
#  5   hla_match_c_high        24180 non-null  float64
#  6   hla_high_res_8          22971 non-null  float64
#  7   tbi_status              28800 non-null  object
#  8   arrhythmia              26598 non-null  object
#  9   hla_low_res_6           25530 non-null  float64
#  10  graft_type              28800 non-null  object
#  11  vent_hist               28541 non-null  object
#  12  renal_issue             26885 non-null  object
#  13  pulm_severe             26665 non-null  object
#  14  prim_disease_hct        28800 non-null  object
#  15  hla_high_res_6          23516 non-null  float64
#  16  cmv_status              28166 non-null  object
#  17  hla_high_res_10         21637 non-null  float64
#  18  hla_match_dqb1_high     23601 non-null  float64
#  19  tce_imm_match           17667 non-null  object
#  20  hla_nmdp_6              24603 non-null  float64
#  21  hla_match_c_low         26000 non-null  float64
#  22  rituximab               26652 non-null  object
#  23  hla_match_drb1_low      26157 non-null  float64
#  24  hla_match_dqb1_low      24606 non-null  float64
#  25  prod_type               28800 non-null  object
#  26  cyto_score_detail       16877 non-null  object
#  27  conditioning_intensity  24011 non-null  object
#  28  ethnicity               28213 non-null  object
#  29  year_hct                28800 non-null  int64
#  30  obesity                 27040 non-null  object
#  31  mrd_hct                 12203 non-null  object
#  32  in_vivo_tcd             28575 non-null  object
#  33  tce_match               9804 non-null   object
#  34  hla_match_a_high        24499 non-null  float64
#  35  hepatic_severe          26929 non-null  object
#  36  donor_age               26992 non-null  float64
#  37  prior_tumor             27122 non-null  object
#  38  hla_match_b_low         26235 non-null  float64
#  39  peptic_ulcer            26381 non-null  object
#  40  age_at_hct              28800 non-null  float64
#  41  hla_match_a_low         26410 non-null  float64
#  42  gvhd_proph              28575 non-null  object
#  43  rheum_issue             26617 non-null  object
#  44  sex_match               28539 non-null  object
#  45  hla_match_b_high        24712 non-null  float64
#  46  race_group              28800 non-null  object
#  47  comorbidity_score       28323 non-null  float64
#  48  karnofsky_score         27930 non-null  float64
#  49  hepatic_mild            26883 non-null  object
#  50  tce_div_match           17404 non-null  object
#  51  donor_related           28642 non-null  object
#  52  melphalan_dose          27395 non-null  object
#  53  hla_low_res_8           25147 non-null  float64
#  54  cardiac                 26258 non-null  object
#  55  hla_match_drb1_high     25448 non-null  float64
#  56  pulm_moderate           26753 non-null  object
#  57  hla_low_res_10          23736 non-null  float64
#  58  efs                     28800 non-null  float64
#  59  efs_time                28800 non-null  float64
# dtypes: float64(23), int64(2), object(35)
# memory usage: 13.2+ MB
# None

# %%
missing_values = trainData.isnull().sum()
missing_values = missing_values.sort_values(ascending=False)
print(missing_values)
# Out:
# tce_match                 18996
# mrd_hct                   16597
# cyto_score_detail         11923
# tce_div_match             11396
# tce_imm_match             11133
# cyto_score                 8068
# hla_high_res_10            7163
# hla_high_res_8             5829
# hla_high_res_6             5284
# hla_match_dqb1_high        5199
# hla_low_res_10             5064
# conditioning_intensity     4789
# hla_match_c_high           4620
# hla_match_a_high           4301
# hla_nmdp_6                 4197
# hla_match_dqb1_low         4194
# hla_match_b_high           4088
# hla_low_res_8              3653
# hla_match_drb1_high        3352
# hla_low_res_6              3270
# hla_match_c_low            2800
# hla_match_drb1_low         2643
# hla_match_b_low            2565
# cardiac                    2542
# peptic_ulcer               2419
# hla_match_a_low            2390
# arrhythmia                 2202
# rheum_issue                2183
# rituximab                  2148
# pulm_severe                2135
# diabetes                   2119
# psych_disturb              2062
# pulm_moderate              2047
# hepatic_mild               1917
# renal_issue                1915
# hepatic_severe             1871
# donor_age                  1808
# obesity                    1760
# prior_tumor                1678
# melphalan_dose             1405
# karnofsky_score             870
# cmv_status                  634
# ethnicity                   587
# comorbidity_score           477
# sex_match                   261
# vent_hist                   259
# in_vivo_tcd                 225
# gvhd_proph                  225
# donor_related               158
# dri_score                   154
# efs                           0
# ID                            0
# race_group                    0
# age_at_hct                    0
# year_hct                      0
# prod_type                     0
# prim_disease_hct              0
# graft_type                    0
# tbi_status                    0
# efs_time                      0
# dtype: int64

# %%
vz.plot_missing_values(trainData)

# %%
missing_values = pp.missing_val_df(trainData)
missing_values = missing_values.merge(dataDict[['variable', 'description']], left_on='variables', right_on='variable', how='left')
missing_values.drop(columns=['variable'], inplace=True)
missing_values.rename(columns={'description': 'Variable Description'}, inplace=True)

missing_values
# Out:
#                  variables  Missing Values  Missing Percent Data Type  \
# 0                tce_match           18996            65.96    object
# 1                  mrd_hct           16597            57.63    object
# 2        cyto_score_detail           11923            41.40    object
# 3            tce_div_match           11396            39.57    object
# 4            tce_imm_match           11133            38.66    object
# 5               cyto_score            8068            28.01    object
# 6          hla_high_res_10            7163            24.87   float64
# 7           hla_high_res_8            5829            20.24   float64
# 8           hla_high_res_6            5284            18.35   float64
# 9      hla_match_dqb1_high            5199            18.05   float64
# 10          hla_low_res_10            5064            17.58   float64
# 11  conditioning_intensity            4789            16.63    object
# 12        hla_match_c_high            4620            16.04   float64
# 13        hla_match_a_high            4301            14.93   float64
# 14              hla_nmdp_6            4197            14.57   float64
# 15      hla_match_dqb1_low            4194            14.56   float64
# 16        hla_match_b_high            4088            14.19   float64
# 17           hla_low_res_8            3653            12.68   float64
# 18     hla_match_drb1_high            3352            11.64   float64
# 19           hla_low_res_6            3270            11.35   float64
# 20         hla_match_c_low            2800             9.72   float64
# 21      hla_match_drb1_low            2643             9.18   float64
# 22         hla_match_b_low            2565             8.91   float64
# 23                 cardiac            2542             8.83    object
# 24            peptic_ulcer            2419             8.40    object
# 25         hla_match_a_low            2390             8.30   float64
# 26              arrhythmia            2202             7.65    object
# 27             rheum_issue            2183             7.58    object
# 28               rituximab            2148             7.46    object
# 29             pulm_severe            2135             7.41    object
# 30                diabetes            2119             7.36    object
# 31           psych_disturb            2062             7.16    object
# 32           pulm_moderate            2047             7.11    object
# 33            hepatic_mild            1917             6.66    object
# 34             renal_issue            1915             6.65    object
# 35          hepatic_severe            1871             6.50    object
# 36               donor_age            1808             6.28   float64
# 37                 obesity            1760             6.11    object
# 38             prior_tumor            1678             5.83    object
# 39          melphalan_dose            1405             4.88    object
# 40         karnofsky_score             870             3.02   float64
# 41              cmv_status             634             2.20    object
# 42               ethnicity             587             2.04    object
# 43       comorbidity_score             477             1.66   float64
# 44               sex_match             261             0.91    object
# 45               vent_hist             259             0.90    object
# 46             in_vivo_tcd             225             0.78    object
# 47              gvhd_proph             225             0.78    object
# 48           donor_related             158             0.55    object
# 49               dri_score             154             0.53    object
# 50                     efs               0             0.00   float64
# 51                      ID               0             0.00     int64
# 52              race_group               0             0.00    object
# 53              age_at_hct               0             0.00   float64
# 54                year_hct               0             0.00     int64
# 55               prod_type               0             0.00    object
# 56        prim_disease_hct               0             0.00    object
# 57              graft_type               0             0.00    object
# 58              tbi_status               0             0.00    object
# 59                efs_time               0             0.00   float64
#
#                                  Variable Description
# 0                             T-cell epitope matching
# 1                        MRD at time of HCT (AML/ALL)
# 2                      Cytogenetics for DRI (AML/MDS)
# 3                             T-cell epitope matching
# 4       T-cell epitope immunogenicity/diversity match
# 5                                   Cytogenetic score
# 6   Recipient / 1st donor allele-level (high resol...
# 7   Recipient / 1st donor allele-level (high resol...
# 8   Recipient / 1st donor allele-level (high resol...
# 9   Recipient / 1st donor allele level (high resol...
# 10                                                NaN
# 11            Computed planned conditioning intensity
# 12  Recipient / 1st donor allele level (high resol...
# 13  Recipient / 1st donor allele level (high resol...
# 14  Recipient / 1st donor matching at HLA-A(lo),-B...
# 15  Recipient / 1st donor antigen level (low resol...
# 16  Recipient / 1st donor allele level (high resol...
# 17  Recipient / 1st donor antigen-level (low resol...
# 18  Recipient / 1st donor allele level (high resol...
# 19  Recipient / 1st donor antigen-level (low resol...
# 20  Recipient / 1st donor antigen level (low resol...
# 21  Recipient / 1st donor antigen level (low resol...
# 22  Recipient / 1st donor antigen level (low resol...
# 23                                            Cardiac
# 24                                       Peptic ulcer
# 25  Recipient / 1st donor antigen level (low resol...
# 26                                         Arrhythmia
# 27                                      Rheumatologic
# 28                    Rituximab given in conditioning
# 29                                  Pulmonary, severe
# 30                                           Diabetes
# 31                            Psychiatric disturbance
# 32                                Pulmonary, moderate
# 33                                      Hepatic, mild
# 34                           Renal, moderate / severe
# 35                         Hepatic, moderate / severe
# 36                                          Donor age
# 37                                            Obesity
# 38                                 Solid tumor, prior
# 39                            Melphalan dose (mg/m^2)
# 40                                         KPS at HCT
# 41                     Donor/recipient CMV serostatus
# 42                                          Ethnicity
# 43                           Sorror comorbidity score
# 44                          Donor/recipient sex match
# 45                  History of mechanical ventilation
# 46         In-vivo T-cell depletion (ATG/alemtuzumab)
# 47                           Planned GVHD prophylaxis
# 48                        Related vs. unrelated donor
# 49                         Refined disease risk index
# 50                                Event-free survival
# 51                                                NaN
# 52                                               Race
# 53                                         Age at HCT
# 54                                        Year of HCT
# 55                                       Product type
# 56                            Primary disease for HCT
# 57                                         Graft type
# 58                                                TBI
# 59                Time to event-free survival, months

# %%
# Detect duplicate rows
duplicate_rows = trainData[trainData.duplicated()]

# Show duplicate rows
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [ID, dri_score, psych_disturb, cyto_score, diabetes, hla_match_c_high, hla_high_res_8, tbi_status, arrhythmia, hla_low_res_6, graft_type, vent_hist, renal_issue, pulm_severe, prim_disease_hct, hla_high_res_6, cmv_status, hla_high_res_10, hla_match_dqb1_high, tce_imm_match, hla_nmdp_6, hla_match_c_low, rituximab, hla_match_drb1_low, hla_match_dqb1_low, prod_type, cyto_score_detail, conditioning_intensity, ethnicity, year_hct, obesity, mrd_hct, in_vivo_tcd, tce_match, hla_match_a_high, hepatic_severe, donor_age, prior_tumor, hla_match_b_low, peptic_ulcer, age_at_hct, hla_match_a_low, gvhd_proph, rheum_issue, sex_match, hla_match_b_high, race_group, comorbidity_score, karnofsky_score, hepatic_mild, tce_div_match, donor_related, melphalan_dose, hla_low_res_8, cardiac, hla_match_drb1_high, pulm_moderate, hla_low_res_10, efs, efs_time]
# Index: []
#
# [0 rows x 60 columns]

# %% [markdown]
# # Data Preprocessing

# %%
trainData_num = pp.numeric_df(trainData)
trainData_num
# Out:
#           ID  hla_match_c_high  hla_high_res_8  hla_low_res_6  hla_high_res_6  \
# 0          0               NaN             NaN            6.0             6.0
# 1          1               2.0             8.0            6.0             6.0
# 2          2               2.0             8.0            6.0             6.0
# 3          3               2.0             8.0            6.0             6.0
# 4          4               2.0             8.0            6.0             6.0
# ...      ...               ...             ...            ...             ...
# 28795  28795               2.0             8.0            6.0             6.0
# 28796  28796               1.0             4.0            5.0             3.0
# 28797  28797               2.0             8.0            6.0             6.0
# 28798  28798               1.0             4.0            3.0             3.0
# 28799  28799               2.0             8.0            6.0             6.0
#
#        hla_high_res_10  hla_match_dqb1_high  hla_nmdp_6  hla_match_c_low  \
# 0                  NaN                  2.0         6.0              2.0
# 1                 10.0                  2.0         6.0              2.0
# 2                 10.0                  2.0         6.0              2.0
# 3                 10.0                  2.0         6.0              2.0
# 4                 10.0                  2.0         5.0              2.0
# ...                ...                  ...         ...              ...
# 28795             10.0                  2.0         6.0              2.0
# 28796              6.0                  2.0         4.0              1.0
# 28797             10.0                  2.0         6.0              2.0
# 28798              5.0                  1.0         3.0              1.0
# 28799             10.0                  2.0         6.0              2.0
#
#        hla_match_drb1_low  ...  age_at_hct  hla_match_a_low  hla_match_b_high  \
# 0                     2.0  ...       9.942              2.0               2.0
# 1                     2.0  ...      43.705              2.0               2.0
# 2                     2.0  ...      33.997              2.0               2.0
# 3                     2.0  ...      43.245              2.0               2.0
# 4                     2.0  ...      29.740              2.0               2.0
# ...                   ...  ...         ...              ...               ...
# 28795                 2.0  ...      51.136              2.0               2.0
# 28796                 2.0  ...      18.075              2.0               1.0
# 28797                 2.0  ...      51.005              2.0               2.0
# 28798                 1.0  ...       0.044              1.0               1.0
# 28799                 2.0  ...       1.035              2.0               2.0
#
#        comorbidity_score  karnofsky_score  hla_low_res_8  hla_match_drb1_high  \
# 0                    0.0             90.0            8.0                  2.0
# 1                    3.0             90.0            8.0                  2.0
# 2                    0.0             90.0            8.0                  2.0
# 3                    0.0             90.0            8.0                  2.0
# 4                    1.0             90.0            8.0                  2.0
# ...                  ...              ...            ...                  ...
# 28795                0.0              NaN            8.0                  2.0
# 28796                3.0             90.0            6.0                  1.0
# 28797                5.0             90.0            8.0                  2.0
# 28798                1.0             90.0            4.0                  1.0
# 28799                2.0             90.0            8.0                  2.0
#
#        hla_low_res_10  efs  efs_time
# 0                10.0  0.0    42.356
# 1                10.0  1.0     4.672
# 2                10.0  0.0    19.793
# 3                10.0  0.0   102.349
# 4                10.0  0.0    16.223
# ...               ...  ...       ...
# 28795            10.0  0.0    18.633
# 28796             8.0  1.0     4.892
# 28797            10.0  0.0    23.157
# 28798             5.0  0.0    52.351
# 28799            10.0  0.0    25.158
#
# [28800 rows x 25 columns]

# %%
trainData_cat = pp.get_cat_cols(trainData)
trainData_cat
# Out:
# Index(['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status',
#        'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe',
#        'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab',
#        'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity',
#        'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe',
#        'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match',
#        'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related',
#        'melphalan_dose', 'cardiac', 'pulm_moderate'],
#       dtype='object')
